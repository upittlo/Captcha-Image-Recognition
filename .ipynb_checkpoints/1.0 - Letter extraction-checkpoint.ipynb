# %% [markdown]
# ### Extract each characters from original captcha
#
# - data preprocessing by openCV
# - cut by contours and width (define by historical dataset, rule based)

# %%
import os
import os.path
import cv2
import glob
import imutils

# %% [markdown]
# ### Extract letter from Image

# %%
CAPTCHA_IMAGE_FOLDER = "image_label_file_amazon"
captcha_image_files = glob.glob(os.path.join(CAPTCHA_IMAGE_FOLDER, "*"))
filename = os.path.basename(captcha_image_files[0])
image = cv2.imread(captcha_image_files[0])
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# - glob.glob >> file pattern matching
# - os.path.basename >> extract file name

# %%
CAPTCHA_IMAGE_FOLDER = "image_label_file_amazon"
OUTPUT_FOLDER = "extracted_letter_images_amazon"

## Get a list of all captcha images
## glob.glob >> file pattern matching
captcha_image_files = glob.glob(os.path.join(CAPTCHA_IMAGE_FOLDER, "*"))
counts = {}

## Loop over files

for (i, captcha_image_file) in enumerate(captcha_image_files):
    print("processing image {}/{}".format(i+1,len(captcha_image_files)))
    
    ## Since the filename contains the captcha text
    ## grab the base filename as the text
    
    filename = os.path.basename(captcha_image_file)
    ## split the file name
    captcha_correct_text = os.path.splitext(filename)[0]
    
    ## Load image and convert to grayscale
    image = cv2.imread(captcha_image_file)
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    
    ## Add some extra padding around the image (constant border)
    gray = cv2.copyMakeBorder(gray,20,20,20,20,cv2.BORDER_CONSTANT,value = (255,255,255))
    
    ## threshold the image (convert to black and white)
    ## https://blog.csdn.net/on2way/article/details/46812121
    
    thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
    
    ## find contours (只接受GRAYSCALE IMAGE)
    ## RETR_EXTERNAL >> 外輪廓檢測
    contours = cv2.findContours(thresh.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    
    ## len(contours) >> 幾組輪廓
    # Hack for compatibility with different OpenCV versions
    contours = contours[0] if imutils.is_cv2() else contours[1]
    
    letter_image_regions = []
    
    ## Loop through each of the contours and extract the letters
    ## if contour are too wide, cut it
    letter_left = 6
    for contour in contours:
        
        ## get the rectangle that contains the contour
        
        (x,y,w,h) = cv2.boundingRect(contour)
        if w >10:
            # Compare the width and height of the contour to detect letters that
            # are conjoined into one chunk
            
            if w >=125 and letter_left >=5:
                letters_width = int(w / 5)
                letter_image_regions.append((x, y, letters_width, h))
                letter_image_regions.append((x + letters_width, y, letters_width, h))
                letter_image_regions.append((x + letters_width+letters_width, y, letters_width, h))
                letter_image_regions.append((x + letters_width+letters_width+letters_width, y, letters_width, h))
                letter_image_regions.append((x + letters_width+letters_width+letters_width+letters_width, y, letters_width, h))

                letter_left = letter_left - 5

            elif w >=95 and letter_left >= 4:
                letters_width = int(w / 4)
                letter_image_regions.append((x, y, letters_width, h))
                letter_image_regions.append((x + letters_width, y, letters_width, h))
                letter_image_regions.append((x + letters_width+letters_width, y, letters_width, h))
                letter_image_regions.append((x + letters_width+letters_width+letters_width, y, letters_width, h))

                letter_left = letter_left - 4

            elif w >68 and letter_left >= 3:
                letters_width = int(w / 3)
                letter_image_regions.append((x, y, letters_width, h))
                letter_image_regions.append((x + letters_width, y, letters_width, h))
                letter_image_regions.append((x + letters_width+letters_width, y, letters_width, h))

                letter_left = letter_left - 3

            elif w >=38 and letter_left >= 2:
                half_width = int(w / 2)
                letter_image_regions.append((x, y, half_width, h))
                letter_image_regions.append((x + half_width, y, half_width, h))

                letter_left = letter_left - 2

            else:
                letter_image_regions.append((x, y, w, h))
                letter_left = letter_left - 1            
         
    if len(letter_image_regions) != 6:
        print("length not equal to six")
        print(captcha_correct_text)
        continue
        
    letter_image_regions = sorted(letter_image_regions,key = lambda x: x[0])
    
    ## Save letter as a single image
    
    for letter_bounding_box,letter_text in zip(letter_image_regions,captcha_correct_text):
        # Grab the coordinates of the letter in the image
        
        x,y,w,h = letter_bounding_box
        # Extract the letter from the original image with a 2-pixel margin around the edge
        letter_image = gray[y - 2:y + h + 2, x - 2:x + w + 2]
        
        # Get the folder to save the image in
        
        save_path = os.path.join(OUTPUT_FOLDER,letter_text)
        
        # if the output directory does not exist, create it
        if not os.path.exists(save_path):
            os.makedirs(save_path)    
           
        # write the letter image to a file
        ## dict.get(key,default)
        count = counts.get(letter_text,1)
        p = os.path.join(save_path, "{}.png".format(str(count).zfill(6)))
        cv2.imwrite(p, letter_image)

        # increment the count for the current key
        counts[letter_text] = count + 1
# Out:
# processing image 1/733
# processing image 2/733
# processing image 3/733
# processing image 4/733
# processing image 5/733
# processing image 6/733
# processing image 7/733
# processing image 8/733
# processing image 9/733
# processing image 10/733
# processing image 11/733
# processing image 12/733
# processing image 13/733
# processing image 14/733
# processing image 15/733
# processing image 16/733
# processing image 17/733
# processing image 18/733
# processing image 19/733
# processing image 20/733
# processing image 21/733
# processing image 22/733
# processing image 23/733
# processing image 24/733
# processing image 25/733
# processing image 26/733
# processing image 27/733
# processing image 28/733
# processing image 29/733
# processing image 30/733
# processing image 31/733
# processing image 32/733
# processing image 33/733
# processing image 34/733
# processing image 35/733
# processing image 36/733
# processing image 37/733
# processing image 38/733
# processing image 39/733
# processing image 40/733
# processing image 41/733
# processing image 42/733
# processing image 43/733
# processing image 44/733
# processing image 45/733
# processing image 46/733
# processing image 47/733
# processing image 48/733
# processing image 49/733
# processing image 50/733
# processing image 51/733
# processing image 52/733
# processing image 53/733
# processing image 54/733
# processing image 55/733
# processing image 56/733
# processing image 57/733
# processing image 58/733
# processing image 59/733
# processing image 60/733
# processing image 61/733
# processing image 62/733
# processing image 63/733
# processing image 64/733
# processing image 65/733
# processing image 66/733
# processing image 67/733
# processing image 68/733
# processing image 69/733
# processing image 70/733
# processing image 71/733
# processing image 72/733
# processing image 73/733
# processing image 74/733
# processing image 75/733
# processing image 76/733
# processing image 77/733
# processing image 78/733
# processing image 79/733
# processing image 80/733
# processing image 81/733
# processing image 82/733
# processing image 83/733
# processing image 84/733
# processing image 85/733
# processing image 86/733
# processing image 87/733
# processing image 88/733
# processing image 89/733
# processing image 90/733
# processing image 91/733
# processing image 92/733
# processing image 93/733
# processing image 94/733
# processing image 95/733
# processing image 96/733
# processing image 97/733
# processing image 98/733
# processing image 99/733
# processing image 100/733
# processing image 101/733
# processing image 102/733
# processing image 103/733
# processing image 104/733
# processing image 105/733
# processing image 106/733
# processing image 107/733
# processing image 108/733
# processing image 109/733
# processing image 110/733
# processing image 111/733
# processing image 112/733
# processing image 113/733
# processing image 114/733
# processing image 115/733
# processing image 116/733
# processing image 117/733
# processing image 118/733
# processing image 119/733
# processing image 120/733
# processing image 121/733
# processing image 122/733
# processing image 123/733
# processing image 124/733
# processing image 125/733
# processing image 126/733
# processing image 127/733
# processing image 128/733
# processing image 129/733
# processing image 130/733
# processing image 131/733
# processing image 132/733
# processing image 133/733
# processing image 134/733
# processing image 135/733
# processing image 136/733
# processing image 137/733
# processing image 138/733
# processing image 139/733
# processing image 140/733
# processing image 141/733
# processing image 142/733
# processing image 143/733
# processing image 144/733
# processing image 145/733
# processing image 146/733
# processing image 147/733
# processing image 148/733
# processing image 149/733
# processing image 150/733
# processing image 151/733
# processing image 152/733
# processing image 153/733
# processing image 154/733
# processing image 155/733
# processing image 156/733
# processing image 157/733
# processing image 158/733
# processing image 159/733
# processing image 160/733
# processing image 161/733
# processing image 162/733
# processing image 163/733
# processing image 164/733
# processing image 165/733
# processing image 166/733
# processing image 167/733
# processing image 168/733
# processing image 169/733
# processing image 170/733
# processing image 171/733
# processing image 172/733
# processing image 173/733
# processing image 174/733
# processing image 175/733
# processing image 176/733
# processing image 177/733
# processing image 178/733
# processing image 179/733
# processing image 180/733
# processing image 181/733
# processing image 182/733
# processing image 183/733
# processing image 184/733
# processing image 185/733
# processing image 186/733
# processing image 187/733
# processing image 188/733
# processing image 189/733
# processing image 190/733
# processing image 191/733
# processing image 192/733
# processing image 193/733
# processing image 194/733
# processing image 195/733
# processing image 196/733
# processing image 197/733
# processing image 198/733
# processing image 199/733
# processing image 200/733
# processing image 201/733
# processing image 202/733
# processing image 203/733
# processing image 204/733
# processing image 205/733
# processing image 206/733
# processing image 207/733
# processing image 208/733
# processing image 209/733
# processing image 210/733
# processing image 211/733
# processing image 212/733
# processing image 213/733
# processing image 214/733
# processing image 215/733
# processing image 216/733
# processing image 217/733
# processing image 218/733
# processing image 219/733
# processing image 220/733
# processing image 221/733
# processing image 222/733
# processing image 223/733
# processing image 224/733
# processing image 225/733
# processing image 226/733
# processing image 227/733
# processing image 228/733
# processing image 229/733
# processing image 230/733
# processing image 231/733
# processing image 232/733
# processing image 233/733
# processing image 234/733
# processing image 235/733
# processing image 236/733
# processing image 237/733
# processing image 238/733
# processing image 239/733
# processing image 240/733
# processing image 241/733
# processing image 242/733
# processing image 243/733
# processing image 244/733
# processing image 245/733
# processing image 246/733
# processing image 247/733
# processing image 248/733
# processing image 249/733
# processing image 250/733
# processing image 251/733
# processing image 252/733
# processing image 253/733
# processing image 254/733
# processing image 255/733
# processing image 256/733
# processing image 257/733
# processing image 258/733
# processing image 259/733
# processing image 260/733
# processing image 261/733
# processing image 262/733
# processing image 263/733
# processing image 264/733
# processing image 265/733
# processing image 266/733
# processing image 267/733
# processing image 268/733
# processing image 269/733
# processing image 270/733
# processing image 271/733
# processing image 272/733
# processing image 273/733
# processing image 274/733
# processing image 275/733
# processing image 276/733
# processing image 277/733
# processing image 278/733
# processing image 279/733
# processing image 280/733
# processing image 281/733
# processing image 282/733
# processing image 283/733
# processing image 284/733
# processing image 285/733
# processing image 286/733
# processing image 287/733
# processing image 288/733
# processing image 289/733
# processing image 290/733
# processing image 291/733
# processing image 292/733
# processing image 293/733
# processing image 294/733
# processing image 295/733
# processing image 296/733
# processing image 297/733
# processing image 298/733
# processing image 299/733
# processing image 300/733
# processing image 301/733
# processing image 302/733
# processing image 303/733
# processing image 304/733
# processing image 305/733
# processing image 306/733
# processing image 307/733
# processing image 308/733
# processing image 309/733
# processing image 310/733
# processing image 311/733
# processing image 312/733
# processing image 313/733
# processing image 314/733
# processing image 315/733
# processing image 316/733
# processing image 317/733
# processing image 318/733
# processing image 319/733
# processing image 320/733
# processing image 321/733
# processing image 322/733
# processing image 323/733
# processing image 324/733
# processing image 325/733
# processing image 326/733
# processing image 327/733
# processing image 328/733
# processing image 329/733
# processing image 330/733
# processing image 331/733
# length not equal to six
# JYTTFX
# processing image 332/733
# processing image 333/733
# processing image 334/733
# processing image 335/733
# processing image 336/733
# processing image 337/733
# processing image 338/733
# processing image 339/733
# processing image 340/733
# processing image 341/733
# processing image 342/733
# processing image 343/733
# processing image 344/733
# processing image 345/733
# processing image 346/733
# processing image 347/733
# processing image 348/733
# processing image 349/733
# processing image 350/733
# processing image 351/733
# processing image 352/733
# processing image 353/733
# processing image 354/733
# processing image 355/733
# processing image 356/733
# processing image 357/733
# processing image 358/733
# processing image 359/733
# processing image 360/733
# processing image 361/733
# processing image 362/733
# processing image 363/733
# processing image 364/733
# processing image 365/733
# processing image 366/733
# processing image 367/733
# processing image 368/733
# processing image 369/733
# processing image 370/733
# processing image 371/733
# processing image 372/733
# processing image 373/733
# processing image 374/733
# processing image 375/733
# processing image 376/733
# processing image 377/733
# processing image 378/733
# processing image 379/733
# processing image 380/733
# processing image 381/733
# processing image 382/733
# processing image 383/733
# processing image 384/733
# processing image 385/733
# processing image 386/733
# processing image 387/733
# processing image 388/733
# processing image 389/733
# processing image 390/733
# processing image 391/733
# processing image 392/733
# processing image 393/733
# processing image 394/733
# processing image 395/733
# processing image 396/733
# processing image 397/733
# processing image 398/733
# processing image 399/733
# processing image 400/733
# processing image 401/733
# processing image 402/733
# processing image 403/733
# processing image 404/733
# processing image 405/733
# processing image 406/733
# processing image 407/733
# processing image 408/733
# processing image 409/733
# processing image 410/733
# processing image 411/733
# processing image 412/733
# processing image 413/733
# processing image 414/733
# processing image 415/733
# processing image 416/733
# processing image 417/733
# processing image 418/733
# processing image 419/733
# processing image 420/733
# processing image 421/733
# processing image 422/733
# processing image 423/733
# processing image 424/733
# processing image 425/733
# processing image 426/733
# processing image 427/733
# processing image 428/733
# processing image 429/733
# processing image 430/733
# processing image 431/733
# processing image 432/733
# processing image 433/733
# processing image 434/733
# processing image 435/733
# processing image 436/733
# processing image 437/733
# processing image 438/733
# processing image 439/733
# processing image 440/733
# processing image 441/733
# processing image 442/733
# processing image 443/733
# processing image 444/733
# processing image 445/733
# processing image 446/733
# processing image 447/733
# processing image 448/733
# processing image 449/733
# processing image 450/733
# processing image 451/733
# processing image 452/733
# processing image 453/733
# processing image 454/733
# processing image 455/733
# processing image 456/733
# processing image 457/733
# processing image 458/733
# processing image 459/733
# processing image 460/733
# processing image 461/733
# processing image 462/733
# processing image 463/733
# processing image 464/733
# processing image 465/733
# processing image 466/733
# processing image 467/733
# processing image 468/733
# processing image 469/733
# processing image 470/733
# processing image 471/733
# processing image 472/733
# processing image 473/733
# processing image 474/733
# processing image 475/733
# processing image 476/733
# processing image 477/733
# processing image 478/733
# processing image 479/733
# processing image 480/733
# processing image 481/733
# processing image 482/733
# processing image 483/733
# processing image 484/733
# processing image 485/733
# processing image 486/733
# processing image 487/733
# processing image 488/733
# processing image 489/733
# processing image 490/733
# processing image 491/733
# processing image 492/733
# processing image 493/733
# processing image 494/733
# processing image 495/733
# processing image 496/733
# processing image 497/733
# processing image 498/733
# processing image 499/733
# processing image 500/733
# processing image 501/733
# processing image 502/733
# processing image 503/733
# processing image 504/733
# processing image 505/733
# processing image 506/733
# processing image 507/733
# processing image 508/733
# processing image 509/733
# processing image 510/733
# processing image 511/733
# processing image 512/733
# processing image 513/733
# processing image 514/733
# processing image 515/733
# processing image 516/733
# processing image 517/733
# processing image 518/733
# processing image 519/733
# processing image 520/733
# processing image 521/733
# processing image 522/733
# processing image 523/733
# processing image 524/733
# processing image 525/733
# processing image 526/733
# processing image 527/733
# processing image 528/733
# processing image 529/733
# processing image 530/733
# processing image 531/733
# processing image 532/733
# processing image 533/733
# processing image 534/733
# processing image 535/733
# processing image 536/733
# processing image 537/733
# processing image 538/733
# processing image 539/733
# processing image 540/733
# processing image 541/733
# processing image 542/733
# processing image 543/733
# processing image 544/733
# processing image 545/733
# processing image 546/733
# processing image 547/733
# processing image 548/733
# processing image 549/733
# processing image 550/733
# processing image 551/733
# processing image 552/733
# processing image 553/733
# processing image 554/733
# processing image 555/733
# processing image 556/733
# processing image 557/733
# processing image 558/733
# processing image 559/733
# processing image 560/733
# processing image 561/733
# processing image 562/733
# processing image 563/733
# processing image 564/733
# length not equal to six
# RYHYTT
# processing image 565/733
# processing image 566/733
# processing image 567/733
# processing image 568/733
# processing image 569/733
# length not equal to six
# TEEHXX
# processing image 570/733
# processing image 571/733
# processing image 572/733
# processing image 573/733
# processing image 574/733
# processing image 575/733
# processing image 576/733
# processing image 577/733
# processing image 578/733
# processing image 579/733
# processing image 580/733
# processing image 581/733
# processing image 582/733
# processing image 583/733
# processing image 584/733
# processing image 585/733
# processing image 586/733
# processing image 587/733
# processing image 588/733
# processing image 589/733
# processing image 590/733
# processing image 591/733
# processing image 592/733
# processing image 593/733
# processing image 594/733
# processing image 595/733
# processing image 596/733
# processing image 597/733
# processing image 598/733
# processing image 599/733
# processing image 600/733
# processing image 601/733
# processing image 602/733
# processing image 603/733
# processing image 604/733
# processing image 605/733
# processing image 606/733
# processing image 607/733
# processing image 608/733
# processing image 609/733
# processing image 610/733
# processing image 611/733
# processing image 612/733
# processing image 613/733
# processing image 614/733
# processing image 615/733
# processing image 616/733
# processing image 617/733
# processing image 618/733
# processing image 619/733
# processing image 620/733
# processing image 621/733
# processing image 622/733
# processing image 623/733
# processing image 624/733
# processing image 625/733
# processing image 626/733
# processing image 627/733
# processing image 628/733
# processing image 629/733
# processing image 630/733
# processing image 631/733
# processing image 632/733
# processing image 633/733
# processing image 634/733
# processing image 635/733
# processing image 636/733
# processing image 637/733
# processing image 638/733
# processing image 639/733
# processing image 640/733
# processing image 641/733
# processing image 642/733
# processing image 643/733
# processing image 644/733
# processing image 645/733
# processing image 646/733
# processing image 647/733
# processing image 648/733
# processing image 649/733
# processing image 650/733
# processing image 651/733
# processing image 652/733
# processing image 653/733
# processing image 654/733
# processing image 655/733
# length not equal to six
# XCCYTF
# processing image 656/733
# processing image 657/733
# processing image 658/733
# processing image 659/733
# processing image 660/733
# processing image 661/733
# processing image 662/733
# processing image 663/733
# processing image 664/733
# length not equal to six
# XEXKHH
# processing image 665/733
# processing image 666/733
# processing image 667/733
# processing image 668/733
# processing image 669/733
# processing image 670/733
# processing image 671/733
# processing image 672/733
# length not equal to six
# XKUYTF
# processing image 673/733
# processing image 674/733
# processing image 675/733
# processing image 676/733
# processing image 677/733
# processing image 678/733
# processing image 679/733
# processing image 680/733
# processing image 681/733
# processing image 682/733
# processing image 683/733
# processing image 684/733
# processing image 685/733
# processing image 686/733
# processing image 687/733
# processing image 688/733
# processing image 689/733
# processing image 690/733
# processing image 691/733
# processing image 692/733
# processing image 693/733
# processing image 694/733
# processing image 695/733
# processing image 696/733
# processing image 697/733
# processing image 698/733
# processing image 699/733
# processing image 700/733
# processing image 701/733
# processing image 702/733
# processing image 703/733
# processing image 704/733
# processing image 705/733
# processing image 706/733
# processing image 707/733
# processing image 708/733
# processing image 709/733
# processing image 710/733
# processing image 711/733
# processing image 712/733
# processing image 713/733
# processing image 714/733
# processing image 715/733
# processing image 716/733
# processing image 717/733
# processing image 718/733
# processing image 719/733
# processing image 720/733
# processing image 721/733
# processing image 722/733
# processing image 723/733
# processing image 724/733
# processing image 725/733
# processing image 726/733
# processing image 727/733
# processing image 728/733
# processing image 729/733
# processing image 730/733
# processing image 731/733
# processing image 732/733
# processing image 733/733
